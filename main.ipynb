# %% [markdown]
# # Проект ML
#
# 1. [Постановка задачи](Problem_Definition/main.ipynb)
# 2. [Сбор и изучение данных](Data_Collection_and_Exploration/main.ipynb)
# 3. [Предобработка и инженерия признаков](Data_Preprocessing_and_Feature_Engineering/main.ipynb)
# 4. [Выбор модели](Model_Selection/main.ipynb)
# 5. [Обучение и настройка гиперпараметров](Model_Training_and_Hyperparameter_Tuning/main.ipynb)
# 6. [Оценка и интерпретация](Model_Evaluation_and_Interpretation/main.ipynb)
# 7. [Развертывание](Deployment/main.ipynb)
# 8. [Мониторинг и обслуживание](Monitoring_and_Maintenance/main.ipynb)
# 9. [Документирование и презентация](Documentation_and_Presentation/main.ipynb)
#
# ---
#
# [Математика](Math/main.ipynb)
