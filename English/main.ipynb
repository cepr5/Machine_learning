# %% [markdown]
# # Английский язык
#
# В английском языке порядок слов всегда важен!
#
# [Местоимения](Pronouns/main.ipynb)
#
# ## Правила
#
# [Глагол To be](To_be/main.ipynb)
# [Wh-Questions (слово вопрос)](Wh_Questions/main.ipynb)
# [There is/are (ставим, когда хотим обозначить место нахождение чего-либо где-либо)](There_is_are/main.ipynb)
