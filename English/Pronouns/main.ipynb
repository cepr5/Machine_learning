# %% [markdown]
# # Местоимения
#
# | Местоимение | Перевод |
# |:---:|:---:|
# | I (ед.ч.) | Я |
# | He (ед.ч.) | Он |
# | She (ед.ч.) | Она |
# | It (ед.ч.) | Оно (Предмет, животное) |
# | We (мн.ч.) | Мы |
# | You (мн.ч.) | Вы, ты |
# | They (мн.ч.) | Они |
