# %% [markdown]
# # Wh-Questions
#
# | Вопрос | Перевод |
# |-|-|
# | What | Что? Какой? |
# | When | Когда? |
# | Where | Где? Куда? |
# | Who | Кто? |
# | How old | Сколько лет? |
# | Why | Почему? Зачем? |
