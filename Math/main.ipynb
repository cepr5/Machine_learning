# %% [markdown]
# # Математика
#
# ## Линейная алгебра
#
# [Объяснение линейной алгебры от 3Blue1Brown](3Blue1Brown_linear/main.ipynb)
#
# - [Матрица и матричные операции](Matrix_and_matrix_operations/main.ipynb)
# - [SVD](SVD/main.ipynb)
# - [Диагонализация](Diagonalization/main.ipynb)

# %% [markdown]
# ## Математический анализ
#
# [Объяснение математического анализа от 3Blue1Brown](3Blue1Brown_analysis/main.ipynb)
#
# - [Частная производная и градиент](Partial_derivative/main.ipynb)
# - [Матрица Якоби](Jacobi_matrix/main.ipynb)
# - [Матрица Гессе](Hesse_matrix/main.ipynb)
#
# Справка:
# - Векторная функция - это просто вектор, элементы которого функции

# %% [markdown]
# ## Дискретная математика
#
# - [Множества](Sets/main.ipynb)
# - [Математическая логика](Logic/main.ipynb)
# - [Комбинаторика](Combinatorics/main.ipynb)
# - [Графы](Graphs/main.ipynb)
# - [Отношения](Relationships/main.ipynb)
# - [Дискретная вероятность](Discrete_probability/main.ipynb)
#
# Справка:
# - $\Omega$ и $\omega$ - это одна и та же буква Омега!

# %% [markdown]
# ## Теория вероятности
