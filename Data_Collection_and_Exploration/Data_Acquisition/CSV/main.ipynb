# %% [markdown]
# `import pandas as pd`
#
# `data = pd.read_csv("data.csv" , thousands=',', sep='\t', encoding='utf-8', na_values="n/a") `
#
# - `"data.csv"` - путь к файлу
# - `thousands` - разделитель тысяч
# - `sep` - разделитель столбцов
# - `encoding` - кодировка файла
# - `na_values` - обозначение пропущенных значений

# %%
import pandas as pd

data = pd.read_csv("data.csv" , thousands=',', delimiter='\t', encoding='latinl', na_values="n/a")
