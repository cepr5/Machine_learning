# %% [markdown]
# # Визуализация
#
# `DataFrame.plot(kind='scatter', x="название столбца 1", y='название столбца 2')`

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

penguins = sns.load_dataset('penguins')

_ = penguins.plot(kind='scatter', x='body_mass_g', y='flipper_length_mm')

# %% [markdown]
# Только для числовых атрибутов, показывает значения и их частоты

# %%
_ = penguins.hist(bins=50, figsize=(10,10))
