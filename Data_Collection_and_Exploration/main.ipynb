# %% [markdown]
# # Сбор и изучение данных
#
# 1. [Получение данных](Data_Acquisition/main.ipynb)
# 2. [Операции с данными](Data_Operations/main.ipynb)
# 3. [Визуализация](Visualization/main.ipynb)
# 4. [Внешний осмотр](Data_Inspection/main.ipynb)
