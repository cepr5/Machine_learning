# %% [markdown]
# # Выбор модели
#
# `from sklearn.linear_model import LinearRegression`
# `from sklearn.neighЬors import КNeighЬorsRegressor`
#
# `model = КNeighЬorsRegressor(n_neighЬors=З)`
# `model = LinearRegression()`
